# %%
# Deep Learning mini_Project with Keras #############################################################################################


# There are eight input variables and one output variable (the last column). We will be learning a model to map rows of input variables (X) to an output variable (y), which we often summarize as y = f(X).

# Input Variables (X):
# Number of times pregnant
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# Diastolic blood pressure (mm Hg)
# Triceps skin fold thickness (mm)
# 2-Hour serum insulin (mu U/ml)
# Body mass index (weight in kg/(height in m)^2)
# Diabetes pedigree function
# Age (years)

# Output Variables (y):
# Class variable (0 or 1)

# %%
# Steps :
# Load Data.
# Define Keras Model.
# Compile Keras Model.
# Fit Keras Model.
# Evaluate Keras Model.
# Make Predictions

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

dataset = loadtxt('C:\\Users\\Samira Dihadril\\3) Deep Learning\\pima-indians-diabetes.txt', delimiter=',')

x = dataset[:,0:8]
y = dataset[:,8]

# We are now ready to define our neural network model.

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Now that the model is defined, we can compile it.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 6.4703 - accuracy: 0.5184
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.1570 - accuracy: 0.6632
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9993 - accuracy: 0.6440
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9013 - accuracy: 0.6574
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7841 - accuracy: 0.6799
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7883 - accuracy: 0.7041
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7497 - accuracy: 0.6574
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.6972
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.6958
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.7772
# Accuracy: 77.72

# %%
dataset_prediction = loadtxt('C:\\Users\\Samira Dihadril\\3) Deep Learning\\pima-indians-diabetes_prediction.txt',delimiter=',')
xp = dataset[:,0:8]
yp = dataset[:,8]

predictions = model.predict_classes(xp)
# summarize the first 5 cases
for i in range(4):
    print('%s => %d (expected %d)' % (xp[i].tolist(), predictions[i], yp[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
